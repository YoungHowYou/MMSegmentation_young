# %% [markdown]
# # 训练语义分割模型
#
# 同济子豪兄 2023-2-13 6-12 6-25 6-30

# %% [markdown]
# ## config配置文件（任选其一）
#
# - ZihaoDataset_UNet_20230818.py
#
# - ZihaoDataset_DeepLabV3plus_20230818.py
#
# - ZihaoDataset_PSPNet_20230818.py
#
# - ZihaoDataset_KNet_20230818.py
#
# - ZihaoDataset_Segformer_20230818.py
#
# - ZihaoDataset_Mask2Former_20230818.py
#
# - ZihaoDataset_FastSCNN_20230818.py

# %% [markdown]
# ## 方式一：在命令行中运行（推荐）
#
# ```shell
# cd mmsegmentation
#
# python tools/train.py Zihao-Configs/ZihaoDataset_PSPNet_20230818.py
# ```

# %% [markdown]
# ## 方式二：在Notebook中运行

# %%
# 进入MMSegmentation主目录
import os
os.chdir('mmsegmentation')

# %%
os.getcwd()
# Out:
# 'd:\\desktop\\source\\MMSegmentation_young\\mmsegmentation'

# %%
# 开始训练
# !python tools/train.py Zihao-Configs/ZihaoDataset_KNet_20230818.py
# Out:
# 12/09 22:05:06 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 2080 SUPER
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: n/a
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192930151
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.8.1  (built against CUDA 12.0)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.8.1, CXX_COMPILER=C:/actions-runner/_work/pytorch/pytorch/builder/windows/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /bigobj /FS -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /utf-8 /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=OFF, TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.2+cu121
#     OpenCV: 4.9.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: True
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 12/09 22:05:07 - mmengine - INFO - Config:
# checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_large_patch4_window7_224_22k_20220308-d5bdebaf.pth'
# conv_kernel_size = 1
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         512,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'Watermelon87_Semantic_Seg_Mask/'
# dataset_type = 'ZihaoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=2500,
#         max_keep_ckpts=2,
#         save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=100, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=768,
#         in_index=2,
#         loss_decode=dict(
#             loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=2,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         attn_drop_rate=0.0,
#         depths=[
#             2,
#             2,
#             18,
#             2,
#         ],
#         drop_path_rate=0.3,
#         drop_rate=0.0,
#         embed_dims=192,
#         mlp_ratio=4,
#         num_heads=[
#             6,
#             12,
#             24,
#             48,
#         ],
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_norm=True,
#         qk_scale=None,
#         qkv_bias=True,
#         type='SwinTransformer',
#         use_abs_pos_embed=False,
#         window_size=7),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         kernel_generate_head=dict(
#             align_corners=False,
#             channels=512,
#             dropout_ratio=0.1,
#             in_channels=[
#                 192,
#                 384,
#                 768,
#                 1536,
#             ],
#             in_index=[
#                 0,
#                 1,
#                 2,
#                 3,
#             ],
#             loss_decode=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             norm_cfg=dict(requires_grad=True, type='SyncBN'),
#             num_classes=2,
#             pool_scales=(
#                 1,
#                 2,
#                 3,
#                 6,
#             ),
#             type='UPerHead'),
#         kernel_update_head=[
#             dict(
#                 conv_kernel_size=1,
#                 dropout=0.0,
#                 feat_transform_cfg=dict(
#                     act_cfg=None, conv_cfg=dict(type='Conv2d')),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=512,
#                 kernel_updator_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=256,
#                     in_channels=256,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='KernelUpdator'),
#                 num_classes=150,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_mask_fcs=1,
#                 out_channels=512,
#                 type='KernelUpdateHead',
#                 with_ffn=True),
#             dict(
#                 conv_kernel_size=1,
#                 dropout=0.0,
#                 feat_transform_cfg=dict(
#                     act_cfg=None, conv_cfg=dict(type='Conv2d')),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=512,
#                 kernel_updator_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=256,
#                     in_channels=256,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='KernelUpdator'),
#                 num_classes=150,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_mask_fcs=1,
#                 out_channels=512,
#                 type='KernelUpdateHead',
#                 with_ffn=True),
#             dict(
#                 conv_kernel_size=1,
#                 dropout=0.0,
#                 feat_transform_cfg=dict(
#                     act_cfg=None, conv_cfg=dict(type='Conv2d')),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=512,
#                 kernel_updator_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=256,
#                     in_channels=256,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='KernelUpdator'),
#                 num_classes=150,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_mask_fcs=1,
#                 out_channels=512,
#                 type='KernelUpdateHead',
#                 with_ffn=True),
#         ],
#         num_stages=3,
#         type='IterativeDecodeHead'),
#     pretrained=
#     'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_large_patch4_window7_224_22k_20220308-d5bdebaf.pth',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='BN')
# num_stages = 3
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=1, norm_type=2),
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=6e-05, type='AdamW', weight_decay=0.0005),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             absolute_pos_embed=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             relative_position_bias_table=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1000, start_factor=0.001,
#         type='LinearLR'),
#     dict(
#         begin=1000,
#         by_epoch=False,
#         end=80000,
#         milestones=[
#             60000,
#             72000,
#         ],
#         type='MultiStepLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1000,
#                 1000,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='ZihaoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1000,
#         1000,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=20000, type='IterBasedTrainLoop', val_interval=500)
# train_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     1000,
#                     1000,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='ZihaoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             1000,
#             1000,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1000,
#                 1000,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='ZihaoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/ZihaoDataset-KNet'
#
# 12/09 22:05:11 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 12/09 22:05:11 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.weight:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.weight:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.weight:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.bias:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.bias:weight_decay=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.bias:decay_mult=0.0
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:11 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.weight:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.weight:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.weight:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.bias:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.bias:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.bias:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.weight:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.weight:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.weight:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.bias:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.bias:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.bias:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm2.weight:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm2.weight:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm2.weight:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm2.bias:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm2.bias:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm2.bias:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm1.weight:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm1.weight:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm1.weight:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm1.bias:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm1.bias:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm1.bias:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm2.weight:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm2.weight:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm2.weight:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm2.bias:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm2.bias:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.10.norm2.bias:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm1.weight:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm1.weight:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm1.weight:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm1.bias:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm1.bias:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm1.bias:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm2.weight:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm2.weight:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm2.weight:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm2.bias:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm2.bias:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.11.norm2.bias:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.norm1.weight:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.norm1.weight:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.norm1.weight:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.norm1.bias:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.norm1.bias:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.norm1.bias:decay_mult=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.attn.w_msa.relative_position_bias_table:lr=6e-05
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 12/09 22:05:12 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.12.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# ...
# 12/09 23:36:12 - mmengine - INFO - Iter(train) [17800/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:10:40  time: 0.2933  data_time: 0.0055  memory: 4600  grad_norm: 5.0586  loss: 0.1308  decode.loss_ce.s0: 0.0298  decode.acc_seg.s0: 99.3721  decode.loss_ce.s1: 0.0290  decode.acc_seg.s1: 99.3690  decode.loss_ce.s2: 0.0288  decode.acc_seg.s2: 99.3706  decode.loss_ce.s3: 0.0288  decode.acc_seg.s3: 99.3675  aux.loss_ce: 0.0144  aux.acc_seg: 99.3973
# 12/09 23:36:41 - mmengine - INFO - Iter(train) [17900/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:10:11  time: 0.2888  data_time: 0.0055  memory: 4600  grad_norm: 7.2904  loss: 0.2144  decode.loss_ce.s0: 0.0483  decode.acc_seg.s0: 98.9754  decode.loss_ce.s1: 0.0461  decode.acc_seg.s1: 98.9204  decode.loss_ce.s2: 0.0504  decode.acc_seg.s2: 98.9586  decode.loss_ce.s3: 0.0500  decode.acc_seg.s3: 98.9899  aux.loss_ce: 0.0195  aux.acc_seg: 98.9914
# 12/09 23:37:10 - mmengine - INFO - Exp name: ZihaoDataset_KNet_20230818_20251209_220505
# 12/09 23:37:10 - mmengine - INFO - Iter(train) [18000/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:09:42  time: 0.2887  data_time: 0.0056  memory: 4600  grad_norm: 2.2555  loss: 0.1033  decode.loss_ce.s0: 0.0229  decode.acc_seg.s0: 99.0662  decode.loss_ce.s1: 0.0226  decode.acc_seg.s1: 99.1096  decode.loss_ce.s2: 0.0230  decode.acc_seg.s2: 99.1135  decode.loss_ce.s3: 0.0229  decode.acc_seg.s3: 99.1096  aux.loss_ce: 0.0119  aux.acc_seg: 99.3370
# 12/09 23:37:12 - mmengine - INFO - per class results:
# 12/09 23:37:12 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 91.31 | 95.62 | 95.46 | 95.46  |   95.29   | 95.62  |
# |    red     | 82.01 | 89.78 | 90.12 | 90.12  |   90.46   | 89.78  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 12/09 23:37:12 - mmengine - INFO - Iter(val) [6/6]    aAcc: 93.7700  mIoU: 86.6600  mAcc: 92.7000  mDice: 92.7900  mFscore: 92.7900  mPrecision: 92.8700  mRecall: 92.7000  data_time: 0.0073  time: 0.3909
# 12/09 23:37:41 - mmengine - INFO - Iter(train) [18100/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:09:13  time: 0.2916  data_time: 0.0055  memory: 4600  grad_norm: 4.7722  loss: 0.1533  decode.loss_ce.s0: 0.0342  decode.acc_seg.s0: 99.8001  decode.loss_ce.s1: 0.0345  decode.acc_seg.s1: 99.8169  decode.loss_ce.s2: 0.0356  decode.acc_seg.s2: 99.8077  decode.loss_ce.s3: 0.0350  decode.acc_seg.s3: 99.8024  aux.loss_ce: 0.0140  aux.acc_seg: 99.6948
# 12/09 23:38:10 - mmengine - INFO - Iter(train) [18200/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:08:44  time: 0.2894  data_time: 0.0055  memory: 4600  grad_norm: 6.9670  loss: 0.1760  decode.loss_ce.s0: 0.0370  decode.acc_seg.s0: 96.3806  decode.loss_ce.s1: 0.0406  decode.acc_seg.s1: 96.3196  decode.loss_ce.s2: 0.0412  decode.acc_seg.s2: 96.3020  decode.loss_ce.s3: 0.0418  decode.acc_seg.s3: 96.3211  aux.loss_ce: 0.0153  aux.acc_seg: 96.2532
# 12/09 23:38:39 - mmengine - INFO - Iter(train) [18300/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:08:15  time: 0.2912  data_time: 0.0051  memory: 4600  grad_norm: 136.1824  loss: 0.5295  decode.loss_ce.s0: 0.1435  decode.acc_seg.s0: 98.4322  decode.loss_ce.s1: 0.1193  decode.acc_seg.s1: 98.4383  decode.loss_ce.s2: 0.0995  decode.acc_seg.s2: 98.4428  decode.loss_ce.s3: 0.0960  decode.acc_seg.s3: 98.4375  aux.loss_ce: 0.0713  aux.acc_seg: 98.4985
# 12/09 23:39:08 - mmengine - INFO - Iter(train) [18400/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:07:46  time: 0.2894  data_time: 0.0056  memory: 4600  grad_norm: 15.9876  loss: 0.2325  decode.loss_ce.s0: 0.0514  decode.acc_seg.s0: 98.7526  decode.loss_ce.s1: 0.0531  decode.acc_seg.s1: 98.7297  decode.loss_ce.s2: 0.0540  decode.acc_seg.s2: 98.7152  decode.loss_ce.s3: 0.0534  decode.acc_seg.s3: 98.7129  aux.loss_ce: 0.0206  aux.acc_seg: 98.8075
# 12/09 23:39:37 - mmengine - INFO - Iter(train) [18500/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:07:16  time: 0.2910  data_time: 0.0053  memory: 4600  grad_norm: 35.5324  loss: 1.7963  decode.loss_ce.s0: 0.9734  decode.acc_seg.s0: 74.3813  decode.loss_ce.s1: 0.1811  decode.acc_seg.s1: 75.5257  decode.loss_ce.s2: 0.1608  decode.acc_seg.s2: 76.3596  decode.loss_ce.s3: 0.1586  decode.acc_seg.s3: 76.0117  aux.loss_ce: 0.3224  aux.acc_seg: 76.2138
# 12/09 23:39:39 - mmengine - INFO - per class results:
# 12/09 23:39:39 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 88.98 | 96.16 | 94.17 | 94.17  |   92.26   | 96.16  |
# |    red     | 76.22 | 82.55 | 86.51 | 86.51  |   90.85   | 82.55  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 12/09 23:39:39 - mmengine - INFO - Iter(val) [6/6]    aAcc: 91.8600  mIoU: 82.6000  mAcc: 89.3600  mDice: 90.3400  mFscore: 90.3400  mPrecision: 91.5600  mRecall: 89.3600  data_time: 0.0075  time: 0.3925
# 12/09 23:40:08 - mmengine - INFO - Iter(train) [18600/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:06:47  time: 0.2900  data_time: 0.0054  memory: 4600  grad_norm: 8.0302  loss: 0.2406  decode.loss_ce.s0: 0.0521  decode.acc_seg.s0: 99.2241  decode.loss_ce.s1: 0.0555  decode.acc_seg.s1: 99.2424  decode.loss_ce.s2: 0.0547  decode.acc_seg.s2: 99.2271  decode.loss_ce.s3: 0.0538  decode.acc_seg.s3: 99.2195  aux.loss_ce: 0.0245  aux.acc_seg: 99.0990
# 12/09 23:40:37 - mmengine - INFO - Iter(train) [18700/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:06:18  time: 0.2893  data_time: 0.0055  memory: 4600  grad_norm: 6.5589  loss: 0.3457  decode.loss_ce.s0: 0.0733  decode.acc_seg.s0: 98.7099  decode.loss_ce.s1: 0.0826  decode.acc_seg.s1: 98.6679  decode.loss_ce.s2: 0.0818  decode.acc_seg.s2: 98.6786  decode.loss_ce.s3: 0.0777  decode.acc_seg.s3: 98.6847  aux.loss_ce: 0.0304  aux.acc_seg: 98.6473
# 12/09 23:41:06 - mmengine - INFO - Iter(train) [18800/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:05:49  time: 0.2892  data_time: 0.0057  memory: 4600  grad_norm: 21.9305  loss: 0.2402  decode.loss_ce.s0: 0.0558  decode.acc_seg.s0: 98.5924  decode.loss_ce.s1: 0.0534  decode.acc_seg.s1: 98.6763  decode.loss_ce.s2: 0.0541  decode.acc_seg.s2: 98.6732  decode.loss_ce.s3: 0.0569  decode.acc_seg.s3: 98.6443  aux.loss_ce: 0.0201  aux.acc_seg: 98.3917
# 12/09 23:41:35 - mmengine - INFO - Iter(train) [18900/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:05:20  time: 0.2893  data_time: 0.0055  memory: 4600  grad_norm: 44.3193  loss: 0.3506  decode.loss_ce.s0: 0.0793  decode.acc_seg.s0: 99.7589  decode.loss_ce.s1: 0.0788  decode.acc_seg.s1: 99.7246  decode.loss_ce.s2: 0.0765  decode.acc_seg.s2: 99.7543  decode.loss_ce.s3: 0.0791  decode.acc_seg.s3: 99.7292  aux.loss_ce: 0.0369  aux.acc_seg: 99.5743
# 12/09 23:42:04 - mmengine - INFO - Exp name: ZihaoDataset_KNet_20230818_20251209_220505
# 12/09 23:42:04 - mmengine - INFO - Iter(train) [19000/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:04:51  time: 0.2892  data_time: 0.0052  memory: 4600  grad_norm: 5.4177  loss: 0.1490  decode.loss_ce.s0: 0.0334  decode.acc_seg.s0: 98.2529  decode.loss_ce.s1: 0.0337  decode.acc_seg.s1: 98.2094  decode.loss_ce.s2: 0.0337  decode.acc_seg.s2: 98.2353  decode.loss_ce.s3: 0.0338  decode.acc_seg.s3: 98.2117  aux.loss_ce: 0.0143  aux.acc_seg: 98.5603
# 12/09 23:42:07 - mmengine - INFO - per class results:
# 12/09 23:42:07 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background |  85.0 | 89.68 | 91.89 | 91.89  |   94.22   | 89.68  |
# |    red     | 72.02 |  88.1 | 83.74 | 83.74  |   79.78   |  88.1  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 12/09 23:42:07 - mmengine - INFO - Iter(val) [6/6]    aAcc: 89.1800  mIoU: 78.5100  mAcc: 88.8900  mDice: 87.8100  mFscore: 87.8100  mPrecision: 87.0000  mRecall: 88.8900  data_time: 0.0071  time: 0.3931
# 12/09 23:42:36 - mmengine - INFO - Iter(train) [19100/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:04:22  time: 0.2904  data_time: 0.0054  memory: 4600  grad_norm: 4.0017  loss: 0.1707  decode.loss_ce.s0: 0.0354  decode.acc_seg.s0: 98.6397  decode.loss_ce.s1: 0.0415  decode.acc_seg.s1: 98.6397  decode.loss_ce.s2: 0.0391  decode.acc_seg.s2: 98.6397  decode.loss_ce.s3: 0.0381  decode.acc_seg.s3: 98.6397  aux.loss_ce: 0.0167  aux.acc_seg: 98.6397
# 12/09 23:43:05 - mmengine - INFO - Iter(train) [19200/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:03:52  time: 0.2908  data_time: 0.0053  memory: 4600  grad_norm: 4.6271  loss: 0.1607  decode.loss_ce.s0: 0.0362  decode.acc_seg.s0: 99.4331  decode.loss_ce.s1: 0.0370  decode.acc_seg.s1: 99.4217  decode.loss_ce.s2: 0.0364  decode.acc_seg.s2: 99.4186  decode.loss_ce.s3: 0.0358  decode.acc_seg.s3: 99.4354  aux.loss_ce: 0.0154  aux.acc_seg: 99.4492
# 12/09 23:43:34 - mmengine - INFO - Iter(train) [19300/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:03:23  time: 0.2894  data_time: 0.0055  memory: 4600  grad_norm: 12.5946  loss: 0.2233  decode.loss_ce.s0: 0.0548  decode.acc_seg.s0: 99.1257  decode.loss_ce.s1: 0.0439  decode.acc_seg.s1: 99.1447  decode.loss_ce.s2: 0.0465  decode.acc_seg.s2: 99.1287  decode.loss_ce.s3: 0.0509  decode.acc_seg.s3: 99.1264  aux.loss_ce: 0.0272  aux.acc_seg: 99.1852
# 12/09 23:44:03 - mmengine - INFO - Iter(train) [19400/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:02:54  time: 0.2900  data_time: 0.0056  memory: 4600  grad_norm: 3.1363  loss: 0.1241  decode.loss_ce.s0: 0.0282  decode.acc_seg.s0: 99.1302  decode.loss_ce.s1: 0.0280  decode.acc_seg.s1: 99.1379  decode.loss_ce.s2: 0.0279  decode.acc_seg.s2: 99.1432  decode.loss_ce.s3: 0.0278  decode.acc_seg.s3: 99.1425  aux.loss_ce: 0.0123  aux.acc_seg: 99.0677
# 12/09 23:44:31 - mmengine - INFO - Iter(train) [19500/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:02:25  time: 0.2894  data_time: 0.0053  memory: 4600  grad_norm: 19.2869  loss: 0.2697  decode.loss_ce.s0: 0.0650  decode.acc_seg.s0: 99.9931  decode.loss_ce.s1: 0.0632  decode.acc_seg.s1: 99.9794  decode.loss_ce.s2: 0.0606  decode.acc_seg.s2: 99.9809  decode.loss_ce.s3: 0.0613  decode.acc_seg.s3: 99.9992  aux.loss_ce: 0.0195  aux.acc_seg: 99.8711
# 12/09 23:44:34 - mmengine - INFO - per class results:
# 12/09 23:44:34 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 88.44 | 93.77 | 93.87 | 93.87  |   93.96   | 93.77  |
# |    red     | 76.64 | 86.96 | 86.78 | 86.78  |   86.59   | 86.96  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 12/09 23:44:34 - mmengine - INFO - Iter(val) [6/6]    aAcc: 91.6200  mIoU: 82.5400  mAcc: 90.3700  mDice: 90.3200  mFscore: 90.3200  mPrecision: 90.2700  mRecall: 90.3700  data_time: 0.0070  time: 0.3921
# 12/09 23:45:03 - mmengine - INFO - Iter(train) [19600/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:01:56  time: 0.2895  data_time: 0.0055  memory: 4600  grad_norm: 45.7031  loss: 0.3043  decode.loss_ce.s0: 0.0647  decode.acc_seg.s0: 99.6002  decode.loss_ce.s1: 0.0607  decode.acc_seg.s1: 99.6307  decode.loss_ce.s2: 0.0604  decode.acc_seg.s2: 99.6147  decode.loss_ce.s3: 0.0587  decode.acc_seg.s3: 99.6170  aux.loss_ce: 0.0598  aux.acc_seg: 99.6483
# 12/09 23:45:32 - mmengine - INFO - Iter(train) [19700/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:01:27  time: 0.2898  data_time: 0.0055  memory: 4600  grad_norm: 7.2649  loss: 0.1547  decode.loss_ce.s0: 0.0358  decode.acc_seg.s0: 98.6153  decode.loss_ce.s1: 0.0340  decode.acc_seg.s1: 98.5504  decode.loss_ce.s2: 0.0348  decode.acc_seg.s2: 98.5168  decode.loss_ce.s3: 0.0346  decode.acc_seg.s3: 98.5275  aux.loss_ce: 0.0155  aux.acc_seg: 98.7991
# 12/09 23:46:01 - mmengine - INFO - Iter(train) [19800/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:00:58  time: 0.2905  data_time: 0.0051  memory: 4600  grad_norm: 4.4619  loss: 0.1728  decode.loss_ce.s0: 0.0392  decode.acc_seg.s0: 99.3622  decode.loss_ce.s1: 0.0388  decode.acc_seg.s1: 99.6353  decode.loss_ce.s2: 0.0386  decode.acc_seg.s2: 99.4354  decode.loss_ce.s3: 0.0380  decode.acc_seg.s3: 99.5010  aux.loss_ce: 0.0183  aux.acc_seg: 99.3179
# 12/09 23:46:30 - mmengine - INFO - Iter(train) [19900/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:00:29  time: 0.2894  data_time: 0.0056  memory: 4600  grad_norm: 12.3896  loss: 0.1454  decode.loss_ce.s0: 0.0319  decode.acc_seg.s0: 96.8460  decode.loss_ce.s1: 0.0331  decode.acc_seg.s1: 96.8338  decode.loss_ce.s2: 0.0352  decode.acc_seg.s2: 96.7209  decode.loss_ce.s3: 0.0328  decode.acc_seg.s3: 96.8208  aux.loss_ce: 0.0124  aux.acc_seg: 97.0711
# 12/09 23:46:59 - mmengine - INFO - Exp name: ZihaoDataset_KNet_20230818_20251209_220505
# 12/09 23:46:59 - mmengine - INFO - Iter(train) [20000/20000]  base_lr: 6.0000e-05 lr: 6.0000e-05  eta: 0:00:00  time: 0.2912  data_time: 0.0054  memory: 4600  grad_norm: 6.3291  loss: 0.1733  decode.loss_ce.s0: 0.0385  decode.acc_seg.s0: 95.2179  decode.loss_ce.s1: 0.0418  decode.acc_seg.s1: 94.9760  decode.loss_ce.s2: 0.0375  decode.acc_seg.s2: 95.1187  decode.loss_ce.s3: 0.0368  decode.acc_seg.s3: 95.0432  aux.loss_ce: 0.0187  aux.acc_seg: 94.9760
# 12/09 23:46:59 - mmengine - INFO - Saving checkpoint at 20000 iterations
# 12/09 23:47:27 - mmengine - INFO - per class results:
# 12/09 23:47:27 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 89.81 | 96.34 | 94.63 | 94.63  |   92.98   | 96.34  |
# |    red     | 78.09 | 84.26 | 87.69 | 87.69  |   91.42   | 84.26  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 12/09 23:47:27 - mmengine - INFO - Iter(val) [6/6]    aAcc: 92.5200  mIoU: 83.9500  mAcc: 90.3000  mDice: 91.1600  mFscore: 91.1600  mPrecision: 92.2000  mRecall: 90.3000  data_time: 0.0075  time: 0.3915
# D:\desktop\source\MMSegmentation_young\mmsegmentation\mmseg\models\backbones\swin.py:556: UserWarning: DeprecationWarning: pretrained is deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is deprecated, '
# D:\desktop\source\MMSegmentation_young\mmsegmentation\mmseg\models\decode_heads\decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# D:\desktop\source\MMSegmentation_young\mmsegmentation\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# D:\desktop\source\MMSegmentation_young\mmsegmentation\mmseg\models\losses\cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# D:\desktop\source\MMSegmentation_young\mmsegmentation\mmseg\engine\hooks\visualization_hook.py:60: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %% [markdown]
# ## 如果遇到报错`CUDA out of memeory`，可尝试以下步骤：
#
# 1. 调小 batch size
#
# 2. 左上角`内核-关闭所有内核`，释放其它notebook占用的显存
#
# 3. 重启实例，或者使用显存更高的实例
#
# ## 训练结果（日志、模型权重文件）保存在`work_dirs`目录
